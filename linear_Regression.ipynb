# %%
import pandas as pd
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv('heart_data.csv')

X = df.drop('diagnosis', axis=1)
y = df['diagnosis']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print("X_train", X_train)
print("Y_train", y_train)
# Out:
# X_train      rest_bp  chest_pain  thalassemia  age  fasting_bs  max_hr  \
# 266      160           0            0   69           1     131
# 37       150           2            2   57           1     173
# 16       128           1            0   62           1     140
# 253      115           3            0   43           0     181
# 144      148           3            2   61           0     161
# ..       ...         ...          ...  ...         ...     ...
# 188      152           3            2   57           0      88
# 71       125           3            2   60           0     141
# 106      128           3            2   58           0     130
# 270      140           3            0   42           0     178
# 102      132           1            0   54           1     159
#
#      exercise_angina  gender  st_slope  cholesterol  st_depression  rest_ecg  \
# 266                0       1         1          234            0.1         2
# ...

# %%
X = df[['rest_bp', 'chest_pain', 'thalassemia', 'age', 'fasting_bs', 'max_hr','exercise_angina', 'gender', 'st_slope', 'cholesterol', 'st_depression','rest_ecg', 'num_vessels', 'diagnosis']]
Y = df.iloc[:,-1]

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
print("X_train",X_train)
print("================================================================================================================================")
print("Y_train",y_train)
# Out:
# X_train      rest_bp  chest_pain  thalassemia  age  fasting_bs  max_hr  \
# 273      125           2            2   64           0     131
# 259      108           2            0   54           0     167
# 30       130           2            0   48           0     139
# 22       180           2            2   68           1     150
# 277      138           3            0   61           0     125
# ..       ...         ...          ...  ...         ...     ...
# 188      152           3            2   57           0      88
# 71       125           3            2   60           0     141
# 106      128           3            2   58           0     130
# 270      140           3            0   42           0     178
# 102      132           1            0   54           1     159
#
#      exercise_angina  gender  st_slope  cholesterol  st_depression  rest_ecg  \
# 273                1       1         1          309            1.8         0
# ...

# %%
print("X_test",X_test)
print("========================================================================================================================================")
# Out:
# X_test      rest_bp  chest_pain  thalassemia  age  fasting_bs  max_hr  \
# 167      140           3            0   51           0     186
# 211      140           0            2   40           0     178
# 63       140           3            2   51           0     173
# 154      134           0            0   59           0     162
# 5        110           3            1   57           0     126
# 77       130           3            2   60           0     144
# 183      135           3            2   65           0     127
# 158      130           2            0   41           0     168
# 9        170           0            2   64           0     155
# 139      117           3            2   60           1     160
# 285      138           3            0   62           1     106
# 78       120           2            0   68           0     115
# 92       101           1            2   46           1     156
# 101      160           1            0   71           0     162
# ...

# %%
print("Y_test",y_test)
# Out:
# Y_test 167    0
# 211    0
# 63     1
# 154    1
# 5      0
# 77     1
# 183    1
# 158    0
# 9      0
# 139    1
# 285    1
# 78     0
# 92     0
# 101    0
# 42     1
# 222    1
# 283    0
# 33     0
# 263    1
# 148    1
# 245    0
# 45     1
# 60     0
# 46     0
# 278    1
# 237    0
# 175    0
# 234    0
# 17     0
# 279    0
# 111    1
# 219    0
# 24     1
# 82     0
# 7      0
# 75     1
# 108    1
# 84     0
# 90     1
# 73     1
# 116    0
# 126    0
# 233    0
# 59     0
# 195    1
# 208    1
# 97     1
# 185    1
# 176    0
# 124    1
# 93     1
# 294    0
# 182    0
# 275    0
# 192    0
# 292    1
# 25     1
# 224    0
# 6      0
# 181    1
# Name: diagnosis, dtype: int64

# %%
print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (237, 14)
# y_train shape: (237,)
# X_test shape: (60, 14)
# y_test shape: (60,)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr_preds = lr.predict(X_test)
lr_mae = mean_absolute_error(y_test, lr_preds)
lr_mse = mean_squared_error(y_test, lr_preds)
lr_r2 = r2_score(y_test, lr_preds)

print(f"Linear Regression Mean Absolute Error: {lr_mae}, \nMean Squared Error: {lr_mse}, \nR^2 Score: {lr_r2}")
# Out:
# Linear Regression Mean Absolute Error: 1.8811064910710615e-15,
# Mean Squared Error: 4.958041362059582e-30,
# R^2 Score: 1.0

# %%
print("lr_preds:",lr_preds)
# Out:
# lr_preds: [-1.28900708e-15  3.95260693e-15  1.00000000e+00  1.00000000e+00
#  -2.87079356e-16  1.00000000e+00  1.00000000e+00  1.63874207e-15
#  -2.34576412e-15  1.00000000e+00  1.00000000e+00 -2.90082699e-15
#   2.04180048e-15 -2.90932483e-15  1.00000000e+00  1.00000000e+00
#   1.32802046e-15 -3.01796597e-15  1.00000000e+00  1.00000000e+00
#   2.06265276e-16  1.00000000e+00  1.39202621e-15 -3.03801684e-16
#   1.00000000e+00  1.32168537e-15  7.24489042e-16  3.32583658e-15
#   4.15290822e-16  3.14453871e-15  1.00000000e+00 -1.60438046e-16
#   1.00000000e+00  4.09408929e-15 -2.36985554e-15  1.00000000e+00
#   1.00000000e+00 -9.09394076e-16  1.00000000e+00  1.00000000e+00
#   6.48148794e-16 -4.17827673e-15  3.70929686e-15 -1.16961200e-15
#   1.00000000e+00  1.00000000e+00  1.00000000e+00  1.00000000e+00
#   2.47852049e-15  1.00000000e+00  1.00000000e+00 -2.76329624e-15
#  -4.36968229e-15 -3.28358331e-15  2.91714383e-15  1.00000000e+00
# ...

# %%
columns_to_normalize = ['rest_bp', 'chest_pain', 'thalassemia', 'age', 'fasting_bs', 'max_hr', 'exercise_angina',
                         'gender', 'st_slope', 'cholesterol', 'st_depression', 'rest_ecg', 'num_vessels']
scaler = StandardScaler()
data[columns_to_normalize] = scaler.fit_transform(df[columns_to_normalize])
print(data)
# Out:
#       rest_bp  chest_pain  thalassemia       age  fasting_bs    max_hr  \
# 0   -1.448925    0.873880    -0.874292  1.378929   -0.411450 -0.331806
# 1   -0.659431   -0.164289    -0.874292 -0.502750   -0.411450  0.366795
# 2   -0.321076    0.873880     1.219778 -2.163054   -0.411450  0.279470
# 3    1.032342    0.873880     1.219778  0.936181   -0.411450  0.192145
# 4    0.468418    0.873880     1.219778 -0.945498   -0.411450 -1.292383
# ..        ...         ...          ...       ...         ...       ...
# 292 -0.095506   -0.164289     1.219778  0.825494   -0.411450 -2.296622
# 293 -1.787279    0.873880    -0.874292  0.382746   -0.411450 -1.205058
# 294  0.355633    0.873880    -0.874292  0.493433   -0.411450  1.414697
# 295 -0.095506    0.873880     1.219778  0.161372    2.430427 -2.034647
# 296  1.032342    0.873880     1.219778 -0.502750   -0.411450 -0.943082
#
#      exercise_angina    gender  st_slope  cholesterol  st_depression  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('heart_data.csv')

train_data = data.iloc[:200]
test_data = data.iloc[200:]

plt.figure(figsize=(10, 6))
plt.scatter(train_data['age'], train_data['cholesterol'], color='blue', label='Train Data')
plt.scatter(test_data['age'], test_data['cholesterol'], color='red', label='Test Data')
plt.xlabel('Age')
plt.ylabel('Cholesterol')
plt.title('Scatter Plot of Train and Test Data')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, fmt=".1f", linewidth=.5)
plt.title('Correlation Heatmap of Heart Data Features')
plt.show()

# %%
import seaborn as sns

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('heart_data.csv')

# Split the data into features (X) and target variable (y)
X = data[['rest_bp', 'chest_pain', 'thalassemia', 'age', 'fasting_bs', 'max_hr']]
y = data['diagnosis']

plt.figure(figsize=(10, 6))
plt.scatter(X['rest_bp'], X['max_hr'], c=y, cmap='viridis')
plt.xlabel('Resting Blood Pressure')
plt.ylabel('Maximum Heart Rate')
plt.title('Scatter Plot of Resting Blood Pressure vs. Maximum Heart Rate')
plt.colorbar(label='Diagnosis')
plt.show()

# %%
if 'lr_preds' in data.columns:
    # Visualize lr_preds data
    plt.figure(figsize=(12, 6))
    plt.plot(data['lr_preds'], color='blue', marker='o', linestyle='dashed', linewidth=2, markersize=6)
    plt.title('Visualization of lr_preds Data')
    plt.xlabel('Index')
else:
    print("Column 'lr_preds' does not exist in the DataFrame.")

# %%
sns.pairplot(data = X_train, vars = ['rest_bp', 'chest_pain', 'thalassemia', 'age', 'fasting_bs', 'max_hr','exercise_angina', 'gender', 'st_slope', 'cholesterol', 'st_depression','rest_ecg', 'num_vessels', 'diagnosis'], height = 3.0)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(data=X_train, vars=['rest_bp', 'chest_pain', 'thalassemia', 'age', 'fasting_bs', 'max_hr', 'exercise_angina', 'gender', 'st_slope', 'cholesterol', 'st_depression', 'rest_ecg', 'num_vessels', 'diagnosis'], kind='reg', height=3.0)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
